# %%
import pandas as pd

# %%
all_trails = pd.read_csv('Resources/AllTrails data - nationalpark.csv')
national_parks = pd.read_csv('Resources/National_Parks_cleaned.csv')

# %%
all_trails = all_trails.sort_values('area_name')
all_trails=all_trails.reset_index(drop=True)
park_code = national_parks[["park_name","park_code"]]
# Out:
#       trail_id                                               name  \
# 0     10350967                                 Pretty Marsh Trail
# 1     10009579                                  Valley Peak Trail
# 2     10319881  Cannon Brook, Cadillac South Ridge and Ladder ...
# 3     10239622             Carriage and Around Mountain Road Loop
# 4     10356349               Bubbles Divide via Jordans Pond Path
# ...        ...                                                ...
# 3308  10265216                            Deertrap Mountain Trail
# 3309  10260738                                Lady Mountain Trail
# 3310  10123238  East Rim and East Mesa to Observation Point [C...
# 3311  10012409                              La Verkin Creek Trail
# 3312  10011354                                Hidden Canyon Trail
#
#                  area_name              city_name state_name   country_name  \
# 0     Acadia National Park           Mount Desert      Maine  United States
# 1     Acadia National Park       Southwest Harbor      Maine  United States
# 2     Acadia National Park             Bar Harbor      Maine  United States
# 3     Acadia National Park           Mount Desert      Maine  United States
# 4     Acadia National Park           Mount Desert      Maine  United States
# ...                    ...                    ...        ...            ...
# 3308    Zion National Park             Orderville       Utah  United States
# 3309    Zion National Park             Springdale       Utah  United States
# 3310    Zion National Park  Mount Carmel Junction       Utah  United States
# 3311    Zion National Park              Hurricane       Utah  United States
# 3312    Zion National Park  Mount Carmel Junction       Utah  United States
#
#                                    _geoloc  popularity     length  \
# 0      {'lat': 44.33242, 'lng': -68.40727}      1.8934    965.604
# 1      {'lat': 44.29948, 'lng': -68.31631}      6.5566   4988.954
# 2      {'lat': 44.35166, 'lng': -68.20437}      6.4841   7402.964
# 3      {'lat': 44.31224, 'lng': -68.28545}      6.4578   6598.294
# 4       {'lat': 44.3237, 'lng': -68.24989}      6.4104   6437.360
# ...                                    ...         ...        ...
# 3308  {'lat': 37.26769, 'lng': -112.89949}      9.1917  17059.004
# 3309  {'lat': 37.25205, 'lng': -112.95615}      9.2408   4023.350
# 3310  {'lat': 37.27093, 'lng': -112.93845}      9.4445  11426.314
# 3311  {'lat': 37.45116, 'lng': -113.19181}      7.8973  29933.724
# 3312  {'lat': 37.27089, 'lng': -112.93842}     30.0717   4828.020
#
#       elevation_gain  difficulty_rating    route_type  visitor_usage  \
# 0            19.8120                  1  out and back            1.0
# 1           365.7600                  3  out and back            1.0
# 2           496.8240                  3          loop            2.0
# 3            81.9912                  1          loop            1.0
# 4           289.8648                  3          loop            2.0
# ...              ...                ...           ...            ...
# 3308        402.9456                  5  out and back            1.0
# 3309        812.9016                  5  out and back            2.0
# 3310        849.7824                  5  out and back            3.0
# 3311        708.9648                  3  out and back            2.0
# 3312        283.7688                  3  out and back            3.0
#
#       avg_rating  num_reviews  \
# 0            4.0            2
# 1            4.5           17
# 2            5.0           22
# 3            4.0           32
# 4            4.5           20
# ...          ...          ...
# 3308         4.5           29
# 3309         4.5            9
# 3310         5.0         1025
# 3311         4.5           29
# 3312         4.5          290
#
#                                                features  \
# 0                 ['lake', 'kids', 'views', 'wildlife']
# 1     ['dogs-leash', 'forest', 'kids', 'views', 'wil...
# 2                   ['forest', 'views', 'wild-flowers']
# 3     ['dogs-leash', 'forest', 'lake', 'kids', 'rive...
# 4     ['dogs-leash', 'forest', 'lake', 'views', 'wil...
# ...                                                 ...
# 3308   ['dogs-no', 'views', 'wild-flowers', 'wildlife']
# 3309   ['dogs-no', 'views', 'wild-flowers', 'wildlife']
# 3310  ['dogs-no', 'partially-paved', 'river', 'views...
# 3311          ['dogs-no', 'river', 'views', 'wildlife']
# 3312  ['dogs-no', 'forest', 'partially-paved', 'view...
#
#                                              activities units
# 0                ['birding', 'nature-trips', 'walking']     i
# 1      ['birding', 'hiking', 'nature-trips', 'walking']     i
# 2     ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 3     ['birding', 'hiking', 'nature-trips', 'walking...     i
# 4                 ['birding', 'hiking', 'nature-trips']     i
# ...                                                 ...   ...
# 3308  ['backpacking', 'birding', 'hiking', 'nature-t...     i
# 3309  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 3310  ['hiking', 'nature-trips', 'rock-climbing', 'w...     i
# 3311  ['backpacking', 'camping', 'hiking', 'nature-t...     i
# 3312              ['birding', 'hiking', 'nature-trips']     i
#
# [3313 rows x 18 columns]

# %%
all_trails = all_trails.replace({'Black Canyon of the Gunnison National Park':'Black Canyon Of The Gunnison National Park',
                          'Congaree National Park Wilderness':'Congaree National Park,','Denali National Park':'Denali National Park & Preserve',
                          'Glacier Bay National Park':'Glacier Bay National Park & Preserve','Great Sand Dunes National Park and Preserve':'Great Sand Dunes National Park & Preserve',
                          'Katmai National Park':'Katmai National Park & Preserve','Kings Canyon National Park':'Sequoia & Kings Canyon National Parks',
                          'Sequoia National Park':'Sequoia & Kings Canyon National Parks','Redwood National Park':'Redwood National and State Parks'})
# Out:
# 'acad'

# %%
all_trails['park_code']=''
for index,row in all_trails.iterrows():
    park = row['area_name']
    try:
        code=park_code.loc[(park_code['park_name']==park),['park_code']].values[0][0]
        all_trails.iloc[index,18]=code
    except:
        all_trails.iloc[index,18]='look'

# %%
all_trails
# Out:
#       trail_id                                               name  \
# 0     10350967                                 Pretty Marsh Trail
# 1     10009579                                  Valley Peak Trail
# 2     10319881  Cannon Brook, Cadillac South Ridge and Ladder ...
# 3     10239622             Carriage and Around Mountain Road Loop
# 4     10356349               Bubbles Divide via Jordans Pond Path
# ...        ...                                                ...
# 3308  10265216                            Deertrap Mountain Trail
# 3309  10260738                                Lady Mountain Trail
# 3310  10123238  East Rim and East Mesa to Observation Point [C...
# 3311  10012409                              La Verkin Creek Trail
# 3312  10011354                                Hidden Canyon Trail
#
#                  area_name              city_name state_name   country_name  \
# 0     Acadia National Park           Mount Desert      Maine  United States
# 1     Acadia National Park       Southwest Harbor      Maine  United States
# 2     Acadia National Park             Bar Harbor      Maine  United States
# 3     Acadia National Park           Mount Desert      Maine  United States
# 4     Acadia National Park           Mount Desert      Maine  United States
# ...                    ...                    ...        ...            ...
# 3308    Zion National Park             Orderville       Utah  United States
# 3309    Zion National Park             Springdale       Utah  United States
# 3310    Zion National Park  Mount Carmel Junction       Utah  United States
# 3311    Zion National Park              Hurricane       Utah  United States
# 3312    Zion National Park  Mount Carmel Junction       Utah  United States
#
#                                    _geoloc  popularity     length  \
# 0      {'lat': 44.33242, 'lng': -68.40727}      1.8934    965.604
# 1      {'lat': 44.29948, 'lng': -68.31631}      6.5566   4988.954
# 2      {'lat': 44.35166, 'lng': -68.20437}      6.4841   7402.964
# 3      {'lat': 44.31224, 'lng': -68.28545}      6.4578   6598.294
# 4       {'lat': 44.3237, 'lng': -68.24989}      6.4104   6437.360
# ...                                    ...         ...        ...
# 3308  {'lat': 37.26769, 'lng': -112.89949}      9.1917  17059.004
# 3309  {'lat': 37.25205, 'lng': -112.95615}      9.2408   4023.350
# 3310  {'lat': 37.27093, 'lng': -112.93845}      9.4445  11426.314
# 3311  {'lat': 37.45116, 'lng': -113.19181}      7.8973  29933.724
# 3312  {'lat': 37.27089, 'lng': -112.93842}     30.0717   4828.020
#
#       elevation_gain  difficulty_rating    route_type  visitor_usage  \
# 0            19.8120                  1  out and back            1.0
# 1           365.7600                  3  out and back            1.0
# 2           496.8240                  3          loop            2.0
# 3            81.9912                  1          loop            1.0
# 4           289.8648                  3          loop            2.0
# ...              ...                ...           ...            ...
# 3308        402.9456                  5  out and back            1.0
# 3309        812.9016                  5  out and back            2.0
# 3310        849.7824                  5  out and back            3.0
# 3311        708.9648                  3  out and back            2.0
# 3312        283.7688                  3  out and back            3.0
#
#       avg_rating  num_reviews  \
# 0            4.0            2
# 1            4.5           17
# 2            5.0           22
# 3            4.0           32
# 4            4.5           20
# ...          ...          ...
# 3308         4.5           29
# 3309         4.5            9
# 3310         5.0         1025
# 3311         4.5           29
# 3312         4.5          290
#
#                                                features  \
# 0                 ['lake', 'kids', 'views', 'wildlife']
# 1     ['dogs-leash', 'forest', 'kids', 'views', 'wil...
# 2                   ['forest', 'views', 'wild-flowers']
# 3     ['dogs-leash', 'forest', 'lake', 'kids', 'rive...
# 4     ['dogs-leash', 'forest', 'lake', 'views', 'wil...
# ...                                                 ...
# 3308   ['dogs-no', 'views', 'wild-flowers', 'wildlife']
# 3309   ['dogs-no', 'views', 'wild-flowers', 'wildlife']
# 3310  ['dogs-no', 'partially-paved', 'river', 'views...
# 3311          ['dogs-no', 'river', 'views', 'wildlife']
# 3312  ['dogs-no', 'forest', 'partially-paved', 'view...
#
#                                              activities units park_code
# 0                ['birding', 'nature-trips', 'walking']     i      acad
# 1      ['birding', 'hiking', 'nature-trips', 'walking']     i      acad
# 2     ['birding', 'hiking', 'nature-trips', 'trail-r...     i      acad
# 3     ['birding', 'hiking', 'nature-trips', 'walking...     i      acad
# 4                 ['birding', 'hiking', 'nature-trips']     i      acad
# ...                                                 ...   ...       ...
# 3308  ['backpacking', 'birding', 'hiking', 'nature-t...     i      zion
# 3309  ['birding', 'hiking', 'nature-trips', 'trail-r...     i      zion
# 3310  ['hiking', 'nature-trips', 'rock-climbing', 'w...     i      zion
# 3311  ['backpacking', 'camping', 'hiking', 'nature-t...     i      zion
# 3312              ['birding', 'hiking', 'nature-trips']     i      zion
#
# [3313 rows x 19 columns]

# %%
look_df=all_trails.loc[all_trails['park_code']=='look']

# %%
look_df['area_name'].unique()
# Out:
# array(['Biscayne National Park',
#        'Clayton Co International Park, Jonesboro GA',
#        'Congaree National Park,', 'Dry Tortugas National Park',
#        'Fort Hunt National Park', 'Fort Pickens National Park',
#        'Gateway Arch National Park'], dtype=object)

# %%
all_trails_cleaned = all_trails.loc[all_trails['park_code']!='look',:]
all_trails_cleaned.to_csv('Resources/all_trails_cleaned.csv')
